# %% [markdown]
# Feature Engineering

# %%
import pandas as pd
import numpy as np

# %%
training = pd.read_csv('final_training.csv')
testing = pd.read_csv('oct_testing.csv')
training.columns
# Out:
# Index(['ViewYN', 'PoolPrivateYN', 'CloseDate', 'ClosePrice', 'Latitude',
#        'Longitude', 'LivingArea', 'CountyOrParish', 'AttachedGarageYN',
#        'ParkingTotal', 'YearBuilt', 'BathroomsTotalInteger', 'City',
#        'BedroomsTotal', 'ContractStatusChangeDate', 'PurchaseContractDate',
#        'ListingContractDate', 'FireplaceYN', 'Stories', 'NewConstructionYN',
#        'GarageSpaces', 'PostalCode', 'PropertyAgeAtClose'],
#       dtype='object')

# %%
#types of columns
boolean_cols = ['ViewYN', 'PoolPrivateYN', 'AttachedGarageYN', 'FireplaceYN']
target_var = 'ClosePrice'
location_cols = ['Latitude', 'Longitude', 'CountyOrParish', 'City', 'PostalCode']
date_cols = ['CloseDate', 'ContractStatusChangeDate', 'PurchaseContractDate', 'ListingContractDate']
age_cols = ['PropertyAgeAtClose', 'YearBuilt']
house_cols = ['LivingArea', 'ParkingTotal', 'BathroomsTotalInteger', 'BedroomsTotal', 'Stories']

# %%
location_df = training[location_cols + [target_var]]
training['ClosePrice'].median()
# Out:
# np.float64(899000.0)

# %%
feature_1 = location_df.groupby('CountyOrParish')[['ClosePrice', 'Latitude', 'Longitude']].mean() #needs to be encoded to is_rich_county: 0 if below 900k, 1 if above 900k
feature_1['is_rich_county'] = feature_1['ClosePrice'].apply(lambda x: 1 if x>= 900_000 else 0)
feature_1
# Out:
#                    ClosePrice   Latitude   Longitude  is_rich_county
# CountyOrParish
# Alameda          1.429271e+06  37.714736 -122.074358               1
# Amador           4.620340e+05  38.450631 -120.652802               0
# Butte            4.956492e+05  39.697101 -121.713891               0
# Calaveras        6.970000e+05  38.098664 -120.571749               0
# Colusa           4.338000e+05  39.231836 -122.085209               0
# Contra Costa     1.225823e+06  37.928328 -121.991530               1
# El Dorado        7.450346e+05  38.768305 -120.586824               0
# Foreign Country  2.950000e+05  31.853187 -116.613551               0
# Fresno           4.984232e+05  36.763681 -119.104024               0
# Glenn            3.885829e+05  39.659481 -122.190831               0
# Humboldt         5.501667e+05  40.532366 -124.097008               0
# Imperial         3.713017e+05  33.075593 -115.729994               0
# ...

# %%
counties_feature = pd.Series(feature_1['is_rich_county'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 counties_feature = pd.Series(feature_1['is_rich_county'])
# ----> 2 location_df.loc[:, counties_feature.index]
#
# File c:\Users\jueeh\idx-exchange-ds34\venv\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File c:\Users\jueeh\idx-exchange-ds34\venv\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# ...
